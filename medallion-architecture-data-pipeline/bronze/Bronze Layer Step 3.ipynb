# %%
df = spark.read.format("delta").load("dbfs:/FileStore/MedallionArchitecture/bronze/Shippers")
df.printSchema()
# Out:
# root
#  |-- ShipperID: integer (nullable = true)
#  |-- CompanyName: string (nullable = true)

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ShipperID</th><th>CompanyName</th></tr></thead><tbody><tr><td>1</td><td>Quik Shipping</td></tr><tr><td>2</td><td>SafeAndFast</td></tr><tr><td>3</td><td>World Wide Transports</td></tr></tbody></table></div>

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Create Tables Using Delta Format and Specify Locations
CREATE TABLE bronze.ArticleCategories
USING DELTA
LOCATION "dbfs:/FileStore/MedallionArchitecture/bronze/ArticleCategories";

CREATE TABLE bronze.Customers
USING DELTA
LOCATION "dbfs:/FileStore/MedallionArchitecture/bronze/Customers";

CREATE TABLE bronze.Divisions
USING DELTA
LOCATION "dbfs:/FileStore/MedallionArchitecture/bronze/Divisions";

CREATE TABLE bronze.OrderDetails
USING DELTA
LOCATION "dbfs:/FileStore/MedallionArchitecture/bronze/OrderDetails";

CREATE TABLE bronze.Orders
USING DELTA
LOCATION "dbfs:/FileStore/MedallionArchitecture/bronze/Orders";

CREATE TABLE bronze.Products
USING DELTA
LOCATION "dbfs:/FileStore/MedallionArchitecture/bronze/Products";

CREATE TABLE bronze.Shipments
USING DELTA
LOCATION "dbfs:/FileStore/MedallionArchitecture/bronze/Shipments";

CREATE TABLE bronze.Shippers
USING DELTA
LOCATION "dbfs:/FileStore/MedallionArchitecture/bronze/Shippers";
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT *
FROM bronze.Orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT *
FROM bronze.customers
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
